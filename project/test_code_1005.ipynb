# %%
import os
import math
import numpy as np
import pandas as pd
import pywt
import matplotlib.pyplot as plt
from scipy.signal import argrelextrema, find_peaks
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)
import cv2
import glob
import scipy.stats as stats

import random

# %%
all_state_change_point_record = pd.read_csv('./data_save/all_state_change_point_record.csv', header=0)
all_synthetic_trj = pd.read_csv('./data_save/all_synthetic_trj.csv', header=0)

# %%
all_state_change_point_record
# Out:
#      Unnamed: 0  veh_id test_acc test_dec  test_jerk  change_point_time_1  \
# 0             0       0      1.0        -        0.5             6.000000
# 1             0       1      1.0        -        1.0             7.000000
# 2             0       2      1.0        -        1.5             7.333333
# 3             0       3      1.0        -        2.0             7.500000
# 4             0       4      1.0        -        2.5             7.600000
# ..          ...     ...      ...      ...        ...                  ...
# 995           0     995        -     -1.0        0.5             9.500000
# 996           0     996        -     -1.0        1.0            10.500000
# 997           0     997        -     -1.0        1.5            10.833333
# 998           0     998        -     -1.0        2.0            11.000000
# 999           0     999        -     -1.0        2.5            11.100000
#
#      change_point_time_2  zero_acc_time  mid_change_point_time  \
# 0                    8.0            8.0               7.000000
# 1                    8.0            8.0               7.500000
# 2                    8.0            8.0               7.666667
# 3                    8.0            8.0               7.750000
# 4                    8.0            8.0               7.800000
# ..                   ...            ...                    ...
# 995                 11.5           11.5              10.500000
# 996                 11.5           11.5              11.000000
# 997                 11.5           11.5              11.166667
# 998                 11.5           11.5              11.250000
# 999                 11.5           11.5              11.300000
#
#      state_change_label
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ..                  ...
# 995                   4
# 996                   4
# 997                   4
# 998                   4
# 999                   4
#
# [1000 rows x 10 columns]

# %%
all_synthetic_trj
# Out:
#         Unnamed: 0  veh_id  local_time  position  speed  acceleration  \
# 0                0       0         0.0    0.0000    0.0           1.0
# 1                1       0         0.1    0.0050    0.1           1.0
# 2                2       0         0.2    0.0200    0.2           1.0
# 3                3       0         0.3    0.0450    0.3           1.0
# 4                4       0         0.4    0.0800    0.4           1.0
# ...            ...     ...         ...       ...    ...           ...
# 199995         195     999        19.5   63.8525    0.0           0.0
# 199996         196     999        19.6   63.8525    0.0           0.0
# 199997         197     999        19.7   63.8525    0.0           0.0
# 199998         198     999        19.8   63.8525    0.0           0.0
# 199999         199     999        19.9   63.8525    0.0           0.0
#
#         state_change_label
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 199995                   4
# 199996                   4
# 199997                   4
# 199998                   4
# 199999                   4
#
# [200000 rows x 7 columns]
