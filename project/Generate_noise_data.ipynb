# %%
import os
import math
import numpy as np
import pandas as pd
import pywt
import matplotlib.pyplot as plt
from scipy.signal import argrelextrema, find_peaks
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)
import cv2
import glob
import scipy.stats as stats

# %%
import random
mu = 0
sigma = 0.12
# mu : mean
# sigma : standard deviation

# %%
#def wavelet_detection_synthetic_trajectory():
def time_acc_dec_jerk_def():
    # state_change_label: 0 for A-F, 1 for A-D, 2 for S-A, 3 for F-D, 4 for D-S
    total_time_step = 200
    time_resolution = 0.1
    
    acceleration_range = [1, 3]
    acc_resolution = 0.5
    # (3-1)/0.5 + 1 = 5
    total_num_acc = int((acceleration_range[1] - acceleration_range[0]) / acc_resolution) + 1
    
    deceleration_range = [-3, -1]
    dec_resolution = 0.5
    total_num_dec = int((deceleration_range[1] - deceleration_range[0]) / dec_resolution) + 1
    
    # absolute_jerk_value = 2  # absolute value
    jerk_value_range = [0.5, 1, 1.5, 2, 2.5]  # absolute value
    change_point_range = [8, 12]
    change_point_resolution = 0.5
    # (12-8)/0.5 = 8
    total_num_change_point = int((change_point_range[1] - change_point_range[0]) / change_point_resolution)
    
    return total_time_step, time_resolution, acceleration_range, acc_resolution, total_num_acc, deceleration_range, dec_resolution, total_num_dec, jerk_value_range, change_point_range, change_point_resolution, total_num_change_point

# %%
def A_F_trajectory_generation():
    global all_state_change_point_record
    global all_synthetic_trj
    
    current_state_change_label = 0
    current_starting_speed = 0
    current_veh_id = 0
    
    total_time_step, time_resolution, acceleration_range, acc_resolution, total_num_acc, deceleration_range, dec_resolution, total_num_dec, jerk_value_range, change_point_range, change_point_resolution, total_num_change_point = time_acc_dec_jerk_def()
    
    # i in {0, 1, ... 7}
    for i in range(total_num_change_point):
        # {8, 8.5, 9, ...11.5}
        current_change_point_time = change_point_range[0] + i * change_point_resolution
        # {0, 1, ... 4}
        for j in range(total_num_acc):
            # {1, 1.5, 2, ... 3}
            current_acc = acceleration_range[0] + acc_resolution * j
            # {0, 1, ... 4}
            for k in range(len(jerk_value_range)):
                current_absolute_jerk = jerk_value_range[k]
                
                # print some info
                print_str = 'Current generating ' + str(current_veh_id) + 'th vehicle synthetic trajectory '
                print(print_str)
                
                # init data space
                single_scenario_trj = pd.DataFrame(np.zeros((total_time_step, 6)), 
                                                   columns=['veh_id', 'local_time', 'position', 
                                                            'speed', 'acceleration', 'state_change_label'])
                single_change_point_record = pd.DataFrame(np.zeros((1, 9)), 
                                                          columns=['veh_id', 'test_acc', 'test_dec', 'test_jerk', 
                                                                   'change_point_time_1', 'change_point_time_2', 
                                                                   'zero_acc_time', 'mid_change_point_time', 
                                                                   'state_change_label'])
                
                single_change_point_record.loc[:, 'state_change_label'] = current_state_change_label
                single_change_point_record.loc[:, 'veh_id'] = current_veh_id
                single_change_point_record.loc[:, 'test_acc'] = current_acc
                single_change_point_record.loc[:, 'test_dec'] = '-'
                single_change_point_record.loc[:, 'test_jerk'] = current_absolute_jerk
                # for 1st example: 8 - (1 / 0.5) 
                single_change_point_record.loc[:, 'change_point_time_1'] = current_change_point_time - (current_acc / current_absolute_jerk)
                # 8
                single_change_point_record.loc[:, 'change_point_time_2'] = current_change_point_time
                # 0.5 * (6 + 8) = 7
                single_change_point_record.loc[:, 'mid_change_point_time'] = 0.5 * (single_change_point_record.loc[:, 'change_point_time_1'] + single_change_point_record.loc[:, 'change_point_time_2'])
                # 8
                single_change_point_record.loc[:, 'zero_acc_time'] = current_change_point_time
                # 0
                single_scenario_trj.loc[:, 'state_change_label'] = current_state_change_label
                # 0
                single_scenario_trj.loc[:, 'veh_id'] = current_veh_id
                
                # calculate the acceleration first
                # (8/0.1)
                change_point_step = round(current_change_point_time / time_resolution)
                # 80 - ((1/0.5)/0.1)
                acc_change_step = change_point_step - round((current_acc / current_absolute_jerk) / time_resolution)
                for t_step in range(total_time_step):
                    if t_step <= acc_change_step:
                        single_scenario_trj.loc[t_step, 'acceleration'] = current_acc
                    elif t_step < change_point_step:
                        single_scenario_trj.loc[t_step, 'acceleration'] = single_scenario_trj.loc[t_step - 1, 'acceleration'] - current_absolute_jerk * time_resolution
                    else:
                        single_scenario_trj.loc[t_step, 'acceleration'] = 0
                        
                # update speed and position
                for t_step in range(total_time_step):
                    
                    guass_noise = random.gauss(mu,sigma)
                    
                    single_scenario_trj.loc[t_step, 'local_time'] = t_step * time_resolution
                    if t_step == 0:
                        single_scenario_trj.loc[t_step, 'speed'] = guass_noise + current_starting_speed
                        single_scenario_trj.loc[t_step, 'position'] = 0
                    else:
                        previous_speed = single_scenario_trj.loc[t_step - 1, 'speed']
                        previous_position = single_scenario_trj.loc[t_step - 1, 'position']
                        single_scenario_trj.loc[t_step, 'speed'] = guass_noise + previous_speed + 0.5 * (single_scenario_trj.loc[t_step - 1, 'acceleration'] +single_scenario_trj.loc[t_step, 'acceleration']) * time_resolution
                        single_scenario_trj.loc[t_step, 'position'] = previous_position + 0.5 * (single_scenario_trj.loc[t_step, 'speed'] + previous_speed) * time_resolution
                all_state_change_point_record = all_state_change_point_record.append(single_change_point_record)
                all_synthetic_trj = all_synthetic_trj.append(single_scenario_trj)
                current_veh_id += 1

# %%
def A_D_trajectory_generation():
    global all_state_change_point_record
    global all_synthetic_trj
    
    current_state_change_label = 1
    current_starting_speed = 0
    current_veh_id = 200
    
    total_time_step, time_resolution, acceleration_range, acc_resolution, total_num_acc, deceleration_range, dec_resolution, total_num_dec, jerk_value_range, change_point_range, change_point_resolution, total_num_change_point = time_acc_dec_jerk_def()
    
    # random_deceleration = np.random.uniform(deceleration_range[0], deceleration_range[1], total_num_acc * total_num_change_point)
    for i in range(total_num_change_point):
        current_change_point_time = change_point_range[0] + i * change_point_resolution
        for j in range(total_num_acc):
            current_acc = acceleration_range[0] + acc_resolution * j
            for k in range(len(jerk_value_range)):
                current_absolute_jerk = jerk_value_range[k]
                print_str = 'Current generating ' + str(current_veh_id) + 'th vehicle synthetic trajectory '
                print(print_str)
                # the deceleration will be designated randomly
                # current_dec = random_deceleration[total_num_acc * i + j]
                acc_time = (current_change_point_time - (current_acc / current_absolute_jerk))
                current_dec = -(current_acc * acc_time) / (20 - acc_time)
                current_absolute_dec = abs(current_dec)
                single_scenario_trj = pd.DataFrame(np.zeros((total_time_step, 6)),
                                                   columns=['veh_id', 'local_time', 'position', 'speed', 'acceleration', 'state_change_label'])
                single_change_point_record = pd.DataFrame(np.zeros((1, 9)), columns=['veh_id', 'test_acc', 'test_dec', 'test_jerk',
                                                                   'change_point_time_1',
                                                                   'change_point_time_2',
                                                                   'zero_acc_time',
                                                                   'mid_change_point_time',
                                                                   'state_change_label'])
                single_change_point_record.loc[:, 'state_change_label'] = current_state_change_label
                single_change_point_record.loc[:, 'veh_id'] = current_veh_id
                single_change_point_record.loc[:, 'test_acc'] = current_acc
                single_change_point_record.loc[:, 'test_dec'] = current_dec
                single_change_point_record.loc[:, 'test_jerk'] = current_absolute_jerk
                single_change_point_record.loc[:, 'change_point_time_1'] = current_change_point_time - (current_acc / current_absolute_jerk)
                single_change_point_record.loc[:, 'change_point_time_2'] = current_change_point_time + (current_absolute_dec / current_absolute_jerk)
                single_change_point_record.loc[:, 'zero_acc_time'] = current_change_point_time
                single_change_point_record.loc[:, 'mid_change_point_time'] = 0.5 * (single_change_point_record.loc[:, 'change_point_time_1'] + single_change_point_record.loc[:, 'change_point_time_2'])
                single_scenario_trj.loc[:, 'state_change_label'] = current_state_change_label
                single_scenario_trj.loc[:, 'veh_id'] = current_veh_id
                # calculate the acceleration first
                change_point_step = int(current_change_point_time / time_resolution)
                acc_change_step = change_point_step - round((current_acc / current_absolute_jerk) / time_resolution)
                dec_change_step = change_point_step + round((current_absolute_dec / current_absolute_jerk) / time_resolution)
                for t_step in range(total_time_step):
                    if t_step <= acc_change_step:
                        single_scenario_trj.loc[t_step, 'acceleration'] = current_acc
                    elif t_step < dec_change_step:
                        single_scenario_trj.loc[t_step, 'acceleration'] = single_scenario_trj.loc[t_step - 1, 'acceleration'] - current_absolute_jerk * time_resolution
                    else:
                        single_scenario_trj.loc[t_step, 'acceleration'] = current_dec
                # update speed and position
                for t_step in range(total_time_step):
                    
                    guass_noise = random.gauss(mu,sigma)
                    
                    single_scenario_trj.loc[t_step, 'local_time'] = t_step * time_resolution
                    if t_step == 0:
                        single_scenario_trj.loc[t_step, 'speed'] = current_starting_speed+guass_noise
                        single_scenario_trj.loc[t_step, 'position'] = 0
                    else:
                        previous_speed = single_scenario_trj.loc[t_step - 1, 'speed']
                        previous_position = single_scenario_trj.loc[t_step - 1, 'position']
                        single_scenario_trj.loc[t_step, 'speed'] = guass_noise+previous_speed + 0.5 * (single_scenario_trj.loc[t_step - 1, 'acceleration'] +single_scenario_trj.loc[t_step, 'acceleration']) * time_resolution
                        single_scenario_trj.loc[t_step, 'position'] = previous_position + 0.5 * (single_scenario_trj.loc[t_step, 'speed'] + previous_speed) * time_resolution
                all_state_change_point_record = all_state_change_point_record.append(single_change_point_record)
                all_synthetic_trj = all_synthetic_trj.append(single_scenario_trj)
                current_veh_id += 1

# %%
def S_A_trajectory_generation():
    global all_state_change_point_record
    global all_synthetic_trj
    current_state_change_label = 2
    current_starting_speed = 0
    current_veh_id = 400
    total_time_step, time_resolution, acceleration_range, acc_resolution, total_num_acc, deceleration_range, dec_resolution, total_num_dec, jerk_value_range, change_point_range, change_point_resolution, total_num_change_point = time_acc_dec_jerk_def()
    
    for i in range(total_num_change_point):
        current_change_point_time = change_point_range[0] + i * change_point_resolution
        for j in range(total_num_acc):
            current_acc = acceleration_range[0] + acc_resolution * j
            for k in range(len(jerk_value_range)):
                current_absolute_jerk = jerk_value_range[k]
                print_str = 'Current generating ' + str(current_veh_id) + 'th vehicle synthetic trajectory '
                print(print_str)
                single_scenario_trj = pd.DataFrame(np.zeros((total_time_step, 6)), columns=['veh_id', 'local_time', 'position', 'speed', 'acceleration', 'state_change_label'])
                single_change_point_record = pd.DataFrame(np.zeros((1, 9)), columns=['veh_id', 'test_acc', 'test_dec', 'test_jerk',
                                                                   'change_point_time_1',
                                                                   'change_point_time_2',
                                                                   'zero_acc_time',
                                                                   'mid_change_point_time',
                                                                   'state_change_label'])
                single_change_point_record.loc[:, 'state_change_label'] = current_state_change_label
                single_change_point_record.loc[:, 'veh_id'] = current_veh_id
                single_change_point_record.loc[:, 'test_acc'] = current_acc
                single_change_point_record.loc[:, 'test_dec'] = '-'
                single_change_point_record.loc[:, 'test_jerk'] = current_absolute_jerk
                single_change_point_record.loc[:, 'change_point_time_1'] = current_change_point_time
                single_change_point_record.loc[:, 'change_point_time_2'] = current_change_point_time + (current_acc / current_absolute_jerk)
                single_change_point_record.loc[:, 'zero_acc_time'] = current_change_point_time
                single_change_point_record.loc[:, 'mid_change_point_time'] = 0.5 * (single_change_point_record.loc[:, 'change_point_time_1'] + single_change_point_record.loc[:, 'change_point_time_2'])
                single_scenario_trj.loc[:, 'state_change_label'] = current_state_change_label
                single_scenario_trj.loc[:, 'veh_id'] = current_veh_id
                # calculate the acceleration first
                change_point_step = round(current_change_point_time / time_resolution)
                acc_change_step = change_point_step + round((current_acc / current_absolute_jerk) / time_resolution)
                for t_step in range(total_time_step):
                    if t_step <= change_point_step:
                        single_scenario_trj.loc[t_step, 'acceleration'] = 0
                    elif t_step < acc_change_step:
                        single_scenario_trj.loc[t_step, 'acceleration'] = single_scenario_trj.loc[t_step - 1, 'acceleration'] + current_absolute_jerk * time_resolution
                    else:
                        single_scenario_trj.loc[t_step, 'acceleration'] = current_acc
                # update speed and position
                for t_step in range(total_time_step):
                    
                    guass_noise = random.gauss(mu,sigma)
                    
                    single_scenario_trj.loc[t_step, 'local_time'] = t_step * time_resolution
                    if t_step == 0:
                        single_scenario_trj.loc[t_step, 'speed'] = current_starting_speed+guass_noise
                        single_scenario_trj.loc[t_step, 'position'] = 0
                    else:
                        previous_speed = single_scenario_trj.loc[t_step - 1, 'speed']
                        previous_position = single_scenario_trj.loc[t_step - 1, 'position']
                        single_scenario_trj.loc[t_step, 'speed'] = guass_noise+previous_speed + 0.5 * (single_scenario_trj.loc[t_step - 1, 'acceleration'] +single_scenario_trj.loc[t_step, 'acceleration']) * time_resolution
                        single_scenario_trj.loc[t_step, 'position'] = previous_position + 0.5 * (single_scenario_trj.loc[t_step, 'speed'] + previous_speed) * time_resolution
                all_state_change_point_record = all_state_change_point_record.append(single_change_point_record)
                all_synthetic_trj = all_synthetic_trj.append(single_scenario_trj)
                current_veh_id += 1

# %%
def F_D_trajectory_generation():
    global all_state_change_point_record
    global all_synthetic_trj
    current_state_change_label = 3
    current_starting_speed = 36
    current_veh_id = 600
    total_time_step, time_resolution, acceleration_range, acc_resolution, total_num_acc, deceleration_range, dec_resolution, total_num_dec, jerk_value_range, change_point_range, change_point_resolution, total_num_change_point = time_acc_dec_jerk_def()
    
    for i in range(total_num_change_point):
        current_change_point_time = change_point_range[0] + i * change_point_resolution
        for j in range(total_num_dec):
            current_dec = deceleration_range[0] + dec_resolution * j
            absolute_dec = abs(current_dec)
            for k in range(len(jerk_value_range)):
                current_absolute_jerk = jerk_value_range[k]
                print_str = 'Current generating ' + str(current_veh_id) + 'th vehicle synthetic trajectory '
                print(print_str)
                single_scenario_trj = pd.DataFrame(np.zeros((total_time_step, 6)), columns=['veh_id', 'local_time', 'position', 'speed', 'acceleration', 'state_change_label'])
                single_change_point_record = pd.DataFrame(np.zeros((1, 9)), columns=['veh_id', 'test_acc', 'test_dec', 'test_jerk',
                                                                   'change_point_time_1',
                                                                   'change_point_time_2',
                                                                   'zero_acc_time',
                                                                   'mid_change_point_time',
                                                                   'state_change_label'])
                single_change_point_record.loc[:, 'state_change_label'] = current_state_change_label
                single_change_point_record.loc[:, 'veh_id'] = current_veh_id
                single_change_point_record.loc[:, 'test_acc'] = '-'
                single_change_point_record.loc[:, 'test_dec'] = current_dec
                single_change_point_record.loc[:, 'test_jerk'] = current_absolute_jerk
                single_change_point_record.loc[:, 'change_point_time_1'] = current_change_point_time
                single_change_point_record.loc[:, 'change_point_time_2'] = current_change_point_time + (absolute_dec / current_absolute_jerk)
                single_change_point_record.loc[:, 'zero_acc_time'] = current_change_point_time
                single_change_point_record.loc[:, 'mid_change_point_time'] = 0.5 * (single_change_point_record.loc[:, 'change_point_time_1'] + single_change_point_record.loc[:, 'change_point_time_2'])
                single_scenario_trj.loc[:, 'state_change_label'] = current_state_change_label
                single_scenario_trj.loc[:, 'veh_id'] = current_veh_id
                # calculate the acceleration first
                change_point_step = round(current_change_point_time / time_resolution)
                acc_change_step = change_point_step + round((absolute_dec / current_absolute_jerk) / time_resolution)
                for t_step in range(total_time_step):
                    if t_step <= change_point_step:
                        single_scenario_trj.loc[t_step, 'acceleration'] = 0
                    elif t_step < acc_change_step:
                        single_scenario_trj.loc[t_step, 'acceleration'] = single_scenario_trj.loc[t_step - 1, 'acceleration'] - current_absolute_jerk * time_resolution
                    else:
                        single_scenario_trj.loc[t_step, 'acceleration'] = current_dec
                # update speed and position
                for t_step in range(total_time_step):
                    
                    guass_noise = random.gauss(mu,sigma)
                    
                    single_scenario_trj.loc[t_step, 'local_time'] = t_step * time_resolution
                    if t_step == 0:
                        single_scenario_trj.loc[t_step, 'speed'] = current_starting_speed+guass_noise
                        single_scenario_trj.loc[t_step, 'position'] = 0
                    else:
                        previous_speed = single_scenario_trj.loc[t_step - 1, 'speed']
                        previous_position = single_scenario_trj.loc[t_step - 1, 'position']
                        single_scenario_trj.loc[t_step, 'speed'] = guass_noise+previous_speed + 0.5 * (single_scenario_trj.loc[t_step - 1, 'acceleration'] +single_scenario_trj.loc[t_step, 'acceleration']) * time_resolution
                        single_scenario_trj.loc[t_step, 'position'] = previous_position + 0.5 * (single_scenario_trj.loc[t_step, 'speed'] + previous_speed) * time_resolution
                all_state_change_point_record = all_state_change_point_record.append(single_change_point_record)
                all_synthetic_trj = all_synthetic_trj.append(single_scenario_trj)
                current_veh_id += 1

# %%
def D_S_trajectory_generation():
    global all_state_change_point_record
    global all_synthetic_trj
    current_state_change_label = 4
    # note that starting speed is set dynamically
    current_veh_id = 800
    
    total_time_step, time_resolution, acceleration_range, acc_resolution, total_num_acc, deceleration_range, dec_resolution, total_num_dec, jerk_value_range, change_point_range, change_point_resolution, total_num_change_point = time_acc_dec_jerk_def()
    
    for i in range(total_num_change_point):
        current_change_point_time = change_point_range[0] + i * change_point_resolution
        for j in range(total_num_dec):
            current_dec = deceleration_range[0] + dec_resolution * j
            absolute_dec = abs(current_dec)
            for k in range(len(jerk_value_range)):
                current_absolute_jerk = jerk_value_range[k]
                print_str = 'Current generating ' + str(current_veh_id) + 'th vehicle synthetic trajectory '
                print(print_str)
                current_starting_speed = (current_change_point_time - (absolute_dec / current_absolute_jerk)) * absolute_dec + 0.5 * absolute_dec * (absolute_dec / current_absolute_jerk)
                single_scenario_trj = pd.DataFrame(np.zeros((total_time_step, 6)), columns=['veh_id', 'local_time', 'position', 'speed', 'acceleration', 'state_change_label'])
                single_change_point_record = pd.DataFrame(np.zeros((1, 9)), columns=['veh_id', 'test_acc', 'test_dec', 'test_jerk',
                                                                   'change_point_time_1',
                                                                   'change_point_time_2',
                                                                   'zero_acc_time',
                                                                   'mid_change_point_time',
                                                                   'state_change_label'])
                single_change_point_record.loc[:, 'state_change_label'] = current_state_change_label
                single_change_point_record.loc[:, 'veh_id'] = current_veh_id
                single_change_point_record.loc[:, 'test_acc'] = '-'
                single_change_point_record.loc[:, 'test_dec'] = current_dec
                single_change_point_record.loc[:, 'test_jerk'] = current_absolute_jerk
                single_change_point_record.loc[:, 'change_point_time_1'] = current_change_point_time - (absolute_dec / current_absolute_jerk)
                single_change_point_record.loc[:, 'change_point_time_2'] = current_change_point_time
                single_change_point_record.loc[:, 'zero_acc_time'] = current_change_point_time
                single_change_point_record.loc[:, 'mid_change_point_time'] = 0.5 * (single_change_point_record.loc[:, 'change_point_time_1'] + single_change_point_record.loc[:, 'change_point_time_2'])
                single_scenario_trj.loc[:, 'state_change_label'] = current_state_change_label
                single_scenario_trj.loc[:, 'veh_id'] = current_veh_id
                # calculate the acceleration first
                change_point_step = round(current_change_point_time / time_resolution)
                acc_change_step = change_point_step - round((absolute_dec / current_absolute_jerk) / time_resolution)
                for t_step in range(total_time_step):
                    if t_step <= acc_change_step:
                        single_scenario_trj.loc[t_step, 'acceleration'] = current_dec
                    elif t_step < change_point_step:
                        single_scenario_trj.loc[t_step, 'acceleration'] = single_scenario_trj.loc[t_step - 1, 'acceleration'] + current_absolute_jerk * time_resolution
                    else:
                        single_scenario_trj.loc[t_step, 'acceleration'] = 0
                # update speed and position
                for t_step in range(total_time_step):
                    
                    guass_noise = random.gauss(mu,sigma)
                    
                    single_scenario_trj.loc[t_step, 'local_time'] = t_step * time_resolution
                    if t_step == 0:
                        single_scenario_trj.loc[t_step, 'speed'] = current_starting_speed+guass_noise
                        single_scenario_trj.loc[t_step, 'position'] = 0
                    elif t_step >= change_point_step:
                        previous_speed = single_scenario_trj.loc[t_step - 1, 'speed']
                        previous_position = single_scenario_trj.loc[t_step - 1, 'position']
                        single_scenario_trj.loc[t_step, 'speed'] = 0 +guass_noise
                        single_scenario_trj.loc[t_step, 'position'] = previous_position + 0.5 * (single_scenario_trj.loc[t_step, 'speed'] + previous_speed) * time_resolution
                    else:
                        previous_speed = single_scenario_trj.loc[t_step - 1, 'speed']
                        previous_position = single_scenario_trj.loc[t_step - 1, 'position']
                        single_scenario_trj.loc[t_step, 'speed'] = guass_noise+previous_speed + 0.5 * (single_scenario_trj.loc[t_step - 1, 'acceleration'] +single_scenario_trj.loc[t_step, 'acceleration']) * time_resolution
                        if single_scenario_trj.loc[t_step, 'speed'] < 0:
                            # modify the change point if speed drop to 0 in advance
                            single_scenario_trj.loc[t_step, 'speed'] = 0+guass_noise
                            single_scenario_trj.loc[t_step, 'acceleration'] = 0
                            single_change_point_record.loc[:, 'change_point_time_2'] = t_step * time_resolution
                        single_scenario_trj.loc[t_step, 'position'] = previous_position + 0.5 * (single_scenario_trj.loc[t_step, 'speed'] + previous_speed) * time_resolution
                all_state_change_point_record = all_state_change_point_record.append(single_change_point_record)
                all_synthetic_trj = all_synthetic_trj.append(single_scenario_trj)
                current_veh_id += 1

# %%
synthetic_trj_generation_label = 1
wavelet_scale_sensitivity_analysis_label = 0
wavelet_scale_sensitivity_video_generation = 0
local_maxima_lines_test_label = 0

# %%
if synthetic_trj_generation_label:
    all_state_change_point_record = pd.DataFrame()
    all_synthetic_trj = pd.DataFrame()
    #wavelet_detection_synthetic_trajectory()
    A_F_trajectory_generation()
    A_D_trajectory_generation()
    S_A_trajectory_generation()
    F_D_trajectory_generation()
    D_S_trajectory_generation()
    all_state_change_point_record.to_csv('./data_save/all_state_change_point_record.csv')
    all_synthetic_trj.to_csv('./data_save/all_synthetic_trj.csv')
# Out:
# Current generating 0th vehicle synthetic trajectory
# Current generating 1th vehicle synthetic trajectory
# Current generating 2th vehicle synthetic trajectory
# Current generating 3th vehicle synthetic trajectory
# Current generating 4th vehicle synthetic trajectory
# Current generating 5th vehicle synthetic trajectory
# Current generating 6th vehicle synthetic trajectory
# Current generating 7th vehicle synthetic trajectory
# Current generating 8th vehicle synthetic trajectory
# Current generating 9th vehicle synthetic trajectory
# Current generating 10th vehicle synthetic trajectory
# Current generating 11th vehicle synthetic trajectory
# Current generating 12th vehicle synthetic trajectory
# Current generating 13th vehicle synthetic trajectory
# Current generating 14th vehicle synthetic trajectory
# Current generating 15th vehicle synthetic trajectory
# Current generating 16th vehicle synthetic trajectory
# Current generating 17th vehicle synthetic trajectory
# Current generating 18th vehicle synthetic trajectory
# Current generating 19th vehicle synthetic trajectory
# Current generating 20th vehicle synthetic trajectory
# Current generating 21th vehicle synthetic trajectory
# Current generating 22th vehicle synthetic trajectory
# Current generating 23th vehicle synthetic trajectory
# Current generating 24th vehicle synthetic trajectory
# Current generating 25th vehicle synthetic trajectory
# Current generating 26th vehicle synthetic trajectory
# Current generating 27th vehicle synthetic trajectory
# Current generating 28th vehicle synthetic trajectory
# Current generating 29th vehicle synthetic trajectory
# Current generating 30th vehicle synthetic trajectory
# Current generating 31th vehicle synthetic trajectory
# Current generating 32th vehicle synthetic trajectory
# Current generating 33th vehicle synthetic trajectory
# Current generating 34th vehicle synthetic trajectory
# Current generating 35th vehicle synthetic trajectory
# Current generating 36th vehicle synthetic trajectory
# Current generating 37th vehicle synthetic trajectory
# Current generating 38th vehicle synthetic trajectory
# Current generating 39th vehicle synthetic trajectory
# Current generating 40th vehicle synthetic trajectory
# Current generating 41th vehicle synthetic trajectory
# Current generating 42th vehicle synthetic trajectory
# Current generating 43th vehicle synthetic trajectory
# Current generating 44th vehicle synthetic trajectory
# Current generating 45th vehicle synthetic trajectory
# Current generating 46th vehicle synthetic trajectory
# Current generating 47th vehicle synthetic trajectory
# Current generating 48th vehicle synthetic trajectory
# Current generating 49th vehicle synthetic trajectory
# Current generating 50th vehicle synthetic trajectory
# Current generating 51th vehicle synthetic trajectory
# Current generating 52th vehicle synthetic trajectory
# Current generating 53th vehicle synthetic trajectory
# Current generating 54th vehicle synthetic trajectory
# Current generating 55th vehicle synthetic trajectory
# Current generating 56th vehicle synthetic trajectory
# Current generating 57th vehicle synthetic trajectory
# Current generating 58th vehicle synthetic trajectory
# Current generating 59th vehicle synthetic trajectory
# Current generating 60th vehicle synthetic trajectory
# Current generating 61th vehicle synthetic trajectory
# Current generating 62th vehicle synthetic trajectory
# Current generating 63th vehicle synthetic trajectory
# Current generating 64th vehicle synthetic trajectory
# Current generating 65th vehicle synthetic trajectory
# Current generating 66th vehicle synthetic trajectory
# Current generating 67th vehicle synthetic trajectory
# Current generating 68th vehicle synthetic trajectory
# Current generating 69th vehicle synthetic trajectory
# Current generating 70th vehicle synthetic trajectory
# Current generating 71th vehicle synthetic trajectory
# Current generating 72th vehicle synthetic trajectory
# Current generating 73th vehicle synthetic trajectory
# Current generating 74th vehicle synthetic trajectory
# Current generating 75th vehicle synthetic trajectory
# Current generating 76th vehicle synthetic trajectory
# Current generating 77th vehicle synthetic trajectory
# Current generating 78th vehicle synthetic trajectory
# Current generating 79th vehicle synthetic trajectory
# Current generating 80th vehicle synthetic trajectory
# Current generating 81th vehicle synthetic trajectory
# Current generating 82th vehicle synthetic trajectory
# Current generating 83th vehicle synthetic trajectory
# Current generating 84th vehicle synthetic trajectory
# Current generating 85th vehicle synthetic trajectory
# Current generating 86th vehicle synthetic trajectory
# Current generating 87th vehicle synthetic trajectory
# Current generating 88th vehicle synthetic trajectory
# Current generating 89th vehicle synthetic trajectory
# Current generating 90th vehicle synthetic trajectory
# Current generating 91th vehicle synthetic trajectory
# Current generating 92th vehicle synthetic trajectory
# Current generating 93th vehicle synthetic trajectory
# Current generating 94th vehicle synthetic trajectory
# Current generating 95th vehicle synthetic trajectory
# Current generating 96th vehicle synthetic trajectory
# Current generating 97th vehicle synthetic trajectory
# Current generating 98th vehicle synthetic trajectory
# Current generating 99th vehicle synthetic trajectory
# Current generating 100th vehicle synthetic trajectory
# Current generating 101th vehicle synthetic trajectory
# Current generating 102th vehicle synthetic trajectory
# Current generating 103th vehicle synthetic trajectory
# Current generating 104th vehicle synthetic trajectory
# Current generating 105th vehicle synthetic trajectory
# Current generating 106th vehicle synthetic trajectory
# Current generating 107th vehicle synthetic trajectory
# Current generating 108th vehicle synthetic trajectory
# Current generating 109th vehicle synthetic trajectory
# Current generating 110th vehicle synthetic trajectory
# Current generating 111th vehicle synthetic trajectory
# Current generating 112th vehicle synthetic trajectory
# Current generating 113th vehicle synthetic trajectory
# Current generating 114th vehicle synthetic trajectory
# Current generating 115th vehicle synthetic trajectory
# Current generating 116th vehicle synthetic trajectory
# Current generating 117th vehicle synthetic trajectory
# Current generating 118th vehicle synthetic trajectory
# Current generating 119th vehicle synthetic trajectory
# Current generating 120th vehicle synthetic trajectory
# Current generating 121th vehicle synthetic trajectory
# Current generating 122th vehicle synthetic trajectory
# Current generating 123th vehicle synthetic trajectory
# Current generating 124th vehicle synthetic trajectory
# Current generating 125th vehicle synthetic trajectory
# Current generating 126th vehicle synthetic trajectory
# Current generating 127th vehicle synthetic trajectory
# Current generating 128th vehicle synthetic trajectory
# Current generating 129th vehicle synthetic trajectory
# Current generating 130th vehicle synthetic trajectory
# Current generating 131th vehicle synthetic trajectory
# Current generating 132th vehicle synthetic trajectory
# Current generating 133th vehicle synthetic trajectory
# Current generating 134th vehicle synthetic trajectory
# Current generating 135th vehicle synthetic trajectory
# Current generating 136th vehicle synthetic trajectory
# Current generating 137th vehicle synthetic trajectory
# Current generating 138th vehicle synthetic trajectory
# Current generating 139th vehicle synthetic trajectory
# Current generating 140th vehicle synthetic trajectory
# Current generating 141th vehicle synthetic trajectory
# Current generating 142th vehicle synthetic trajectory
# Current generating 143th vehicle synthetic trajectory
# Current generating 144th vehicle synthetic trajectory
# Current generating 145th vehicle synthetic trajectory
# Current generating 146th vehicle synthetic trajectory
# Current generating 147th vehicle synthetic trajectory
# Current generating 148th vehicle synthetic trajectory
# Current generating 149th vehicle synthetic trajectory
# Current generating 150th vehicle synthetic trajectory
# Current generating 151th vehicle synthetic trajectory
# Current generating 152th vehicle synthetic trajectory
# Current generating 153th vehicle synthetic trajectory
# Current generating 154th vehicle synthetic trajectory
# Current generating 155th vehicle synthetic trajectory
# Current generating 156th vehicle synthetic trajectory
# Current generating 157th vehicle synthetic trajectory
# Current generating 158th vehicle synthetic trajectory
# Current generating 159th vehicle synthetic trajectory
# Current generating 160th vehicle synthetic trajectory
# Current generating 161th vehicle synthetic trajectory
# Current generating 162th vehicle synthetic trajectory
# Current generating 163th vehicle synthetic trajectory
# Current generating 164th vehicle synthetic trajectory
# Current generating 165th vehicle synthetic trajectory
# Current generating 166th vehicle synthetic trajectory
# Current generating 167th vehicle synthetic trajectory
# Current generating 168th vehicle synthetic trajectory
# Current generating 169th vehicle synthetic trajectory
# Current generating 170th vehicle synthetic trajectory
# Current generating 171th vehicle synthetic trajectory
# Current generating 172th vehicle synthetic trajectory
# Current generating 173th vehicle synthetic trajectory
# Current generating 174th vehicle synthetic trajectory
# Current generating 175th vehicle synthetic trajectory
# Current generating 176th vehicle synthetic trajectory
# Current generating 177th vehicle synthetic trajectory
# Current generating 178th vehicle synthetic trajectory
# Current generating 179th vehicle synthetic trajectory
# Current generating 180th vehicle synthetic trajectory
# Current generating 181th vehicle synthetic trajectory
# Current generating 182th vehicle synthetic trajectory
# Current generating 183th vehicle synthetic trajectory
# Current generating 184th vehicle synthetic trajectory
# Current generating 185th vehicle synthetic trajectory
# Current generating 186th vehicle synthetic trajectory
# Current generating 187th vehicle synthetic trajectory
# Current generating 188th vehicle synthetic trajectory
# Current generating 189th vehicle synthetic trajectory
# Current generating 190th vehicle synthetic trajectory
# Current generating 191th vehicle synthetic trajectory
# Current generating 192th vehicle synthetic trajectory
# Current generating 193th vehicle synthetic trajectory
# Current generating 194th vehicle synthetic trajectory
# Current generating 195th vehicle synthetic trajectory
# Current generating 196th vehicle synthetic trajectory
# Current generating 197th vehicle synthetic trajectory
# Current generating 198th vehicle synthetic trajectory
# Current generating 199th vehicle synthetic trajectory
# Current generating 200th vehicle synthetic trajectory
# Current generating 201th vehicle synthetic trajectory
# Current generating 202th vehicle synthetic trajectory
# Current generating 203th vehicle synthetic trajectory
# Current generating 204th vehicle synthetic trajectory
# Current generating 205th vehicle synthetic trajectory
# Current generating 206th vehicle synthetic trajectory
# Current generating 207th vehicle synthetic trajectory
# Current generating 208th vehicle synthetic trajectory
# Current generating 209th vehicle synthetic trajectory
# Current generating 210th vehicle synthetic trajectory
# Current generating 211th vehicle synthetic trajectory
# Current generating 212th vehicle synthetic trajectory
# Current generating 213th vehicle synthetic trajectory
# Current generating 214th vehicle synthetic trajectory
# Current generating 215th vehicle synthetic trajectory
# Current generating 216th vehicle synthetic trajectory
# Current generating 217th vehicle synthetic trajectory
# Current generating 218th vehicle synthetic trajectory
# Current generating 219th vehicle synthetic trajectory
# Current generating 220th vehicle synthetic trajectory
# Current generating 221th vehicle synthetic trajectory
# Current generating 222th vehicle synthetic trajectory
# Current generating 223th vehicle synthetic trajectory
# Current generating 224th vehicle synthetic trajectory
# Current generating 225th vehicle synthetic trajectory
# Current generating 226th vehicle synthetic trajectory
# Current generating 227th vehicle synthetic trajectory
# Current generating 228th vehicle synthetic trajectory
# Current generating 229th vehicle synthetic trajectory
# Current generating 230th vehicle synthetic trajectory
# Current generating 231th vehicle synthetic trajectory
# Current generating 232th vehicle synthetic trajectory
# Current generating 233th vehicle synthetic trajectory
# Current generating 234th vehicle synthetic trajectory
# Current generating 235th vehicle synthetic trajectory
# Current generating 236th vehicle synthetic trajectory
# Current generating 237th vehicle synthetic trajectory
# Current generating 238th vehicle synthetic trajectory
# Current generating 239th vehicle synthetic trajectory
# Current generating 240th vehicle synthetic trajectory
# Current generating 241th vehicle synthetic trajectory
# Current generating 242th vehicle synthetic trajectory
# Current generating 243th vehicle synthetic trajectory
# Current generating 244th vehicle synthetic trajectory
# Current generating 245th vehicle synthetic trajectory
# Current generating 246th vehicle synthetic trajectory
# Current generating 247th vehicle synthetic trajectory
# Current generating 248th vehicle synthetic trajectory
# Current generating 249th vehicle synthetic trajectory
# Current generating 250th vehicle synthetic trajectory
# Current generating 251th vehicle synthetic trajectory
# Current generating 252th vehicle synthetic trajectory
# Current generating 253th vehicle synthetic trajectory
# Current generating 254th vehicle synthetic trajectory
# Current generating 255th vehicle synthetic trajectory
# Current generating 256th vehicle synthetic trajectory
# Current generating 257th vehicle synthetic trajectory
# Current generating 258th vehicle synthetic trajectory
# Current generating 259th vehicle synthetic trajectory
# Current generating 260th vehicle synthetic trajectory
# Current generating 261th vehicle synthetic trajectory
# Current generating 262th vehicle synthetic trajectory
# Current generating 263th vehicle synthetic trajectory
# Current generating 264th vehicle synthetic trajectory
# Current generating 265th vehicle synthetic trajectory
# Current generating 266th vehicle synthetic trajectory
# Current generating 267th vehicle synthetic trajectory
# Current generating 268th vehicle synthetic trajectory
# Current generating 269th vehicle synthetic trajectory
# Current generating 270th vehicle synthetic trajectory
# Current generating 271th vehicle synthetic trajectory
# Current generating 272th vehicle synthetic trajectory
# Current generating 273th vehicle synthetic trajectory
# Current generating 274th vehicle synthetic trajectory
# Current generating 275th vehicle synthetic trajectory
# Current generating 276th vehicle synthetic trajectory
# Current generating 277th vehicle synthetic trajectory
# Current generating 278th vehicle synthetic trajectory
# Current generating 279th vehicle synthetic trajectory
# Current generating 280th vehicle synthetic trajectory
# Current generating 281th vehicle synthetic trajectory
# Current generating 282th vehicle synthetic trajectory
# Current generating 283th vehicle synthetic trajectory
# Current generating 284th vehicle synthetic trajectory
# Current generating 285th vehicle synthetic trajectory
# Current generating 286th vehicle synthetic trajectory
# Current generating 287th vehicle synthetic trajectory
# Current generating 288th vehicle synthetic trajectory
# Current generating 289th vehicle synthetic trajectory
# Current generating 290th vehicle synthetic trajectory
# Current generating 291th vehicle synthetic trajectory
# Current generating 292th vehicle synthetic trajectory
# Current generating 293th vehicle synthetic trajectory
# Current generating 294th vehicle synthetic trajectory
# Current generating 295th vehicle synthetic trajectory
# Current generating 296th vehicle synthetic trajectory
# Current generating 297th vehicle synthetic trajectory
# Current generating 298th vehicle synthetic trajectory
# Current generating 299th vehicle synthetic trajectory
# Current generating 300th vehicle synthetic trajectory
# Current generating 301th vehicle synthetic trajectory
# Current generating 302th vehicle synthetic trajectory
# Current generating 303th vehicle synthetic trajectory
# Current generating 304th vehicle synthetic trajectory
# Current generating 305th vehicle synthetic trajectory
# Current generating 306th vehicle synthetic trajectory
# Current generating 307th vehicle synthetic trajectory
# Current generating 308th vehicle synthetic trajectory
# Current generating 309th vehicle synthetic trajectory
# Current generating 310th vehicle synthetic trajectory
# Current generating 311th vehicle synthetic trajectory
# Current generating 312th vehicle synthetic trajectory
# Current generating 313th vehicle synthetic trajectory
# Current generating 314th vehicle synthetic trajectory
# Current generating 315th vehicle synthetic trajectory
# Current generating 316th vehicle synthetic trajectory
# Current generating 317th vehicle synthetic trajectory
# Current generating 318th vehicle synthetic trajectory
# Current generating 319th vehicle synthetic trajectory
# Current generating 320th vehicle synthetic trajectory
# Current generating 321th vehicle synthetic trajectory
# Current generating 322th vehicle synthetic trajectory
# Current generating 323th vehicle synthetic trajectory
# Current generating 324th vehicle synthetic trajectory
# Current generating 325th vehicle synthetic trajectory
# Current generating 326th vehicle synthetic trajectory
# Current generating 327th vehicle synthetic trajectory
# Current generating 328th vehicle synthetic trajectory
# Current generating 329th vehicle synthetic trajectory
# Current generating 330th vehicle synthetic trajectory
# Current generating 331th vehicle synthetic trajectory
# Current generating 332th vehicle synthetic trajectory
# Current generating 333th vehicle synthetic trajectory
# Current generating 334th vehicle synthetic trajectory
# Current generating 335th vehicle synthetic trajectory
# Current generating 336th vehicle synthetic trajectory
# Current generating 337th vehicle synthetic trajectory
# Current generating 338th vehicle synthetic trajectory
# Current generating 339th vehicle synthetic trajectory
# Current generating 340th vehicle synthetic trajectory
# Current generating 341th vehicle synthetic trajectory
# Current generating 342th vehicle synthetic trajectory
# Current generating 343th vehicle synthetic trajectory
# Current generating 344th vehicle synthetic trajectory
# Current generating 345th vehicle synthetic trajectory
# Current generating 346th vehicle synthetic trajectory
# Current generating 347th vehicle synthetic trajectory
# Current generating 348th vehicle synthetic trajectory
# Current generating 349th vehicle synthetic trajectory
# Current generating 350th vehicle synthetic trajectory
# Current generating 351th vehicle synthetic trajectory
# Current generating 352th vehicle synthetic trajectory
# Current generating 353th vehicle synthetic trajectory
# Current generating 354th vehicle synthetic trajectory
# Current generating 355th vehicle synthetic trajectory
# Current generating 356th vehicle synthetic trajectory
# Current generating 357th vehicle synthetic trajectory
# Current generating 358th vehicle synthetic trajectory
# Current generating 359th vehicle synthetic trajectory
# Current generating 360th vehicle synthetic trajectory
# Current generating 361th vehicle synthetic trajectory
# Current generating 362th vehicle synthetic trajectory
# Current generating 363th vehicle synthetic trajectory
# Current generating 364th vehicle synthetic trajectory
# Current generating 365th vehicle synthetic trajectory
# Current generating 366th vehicle synthetic trajectory
# Current generating 367th vehicle synthetic trajectory
# Current generating 368th vehicle synthetic trajectory
# Current generating 369th vehicle synthetic trajectory
# Current generating 370th vehicle synthetic trajectory
# Current generating 371th vehicle synthetic trajectory
# Current generating 372th vehicle synthetic trajectory
# Current generating 373th vehicle synthetic trajectory
# Current generating 374th vehicle synthetic trajectory
# Current generating 375th vehicle synthetic trajectory
# Current generating 376th vehicle synthetic trajectory
# Current generating 377th vehicle synthetic trajectory
# Current generating 378th vehicle synthetic trajectory
# Current generating 379th vehicle synthetic trajectory
# Current generating 380th vehicle synthetic trajectory
# Current generating 381th vehicle synthetic trajectory
# Current generating 382th vehicle synthetic trajectory
# Current generating 383th vehicle synthetic trajectory
# Current generating 384th vehicle synthetic trajectory
# Current generating 385th vehicle synthetic trajectory
# Current generating 386th vehicle synthetic trajectory
# Current generating 387th vehicle synthetic trajectory
# Current generating 388th vehicle synthetic trajectory
# Current generating 389th vehicle synthetic trajectory
# Current generating 390th vehicle synthetic trajectory
# Current generating 391th vehicle synthetic trajectory
# Current generating 392th vehicle synthetic trajectory
# Current generating 393th vehicle synthetic trajectory
# Current generating 394th vehicle synthetic trajectory
# Current generating 395th vehicle synthetic trajectory
# Current generating 396th vehicle synthetic trajectory
# Current generating 397th vehicle synthetic trajectory
# Current generating 398th vehicle synthetic trajectory
# Current generating 399th vehicle synthetic trajectory
# Current generating 400th vehicle synthetic trajectory
# Current generating 401th vehicle synthetic trajectory
# Current generating 402th vehicle synthetic trajectory
# Current generating 403th vehicle synthetic trajectory
# Current generating 404th vehicle synthetic trajectory
# Current generating 405th vehicle synthetic trajectory
# Current generating 406th vehicle synthetic trajectory
# Current generating 407th vehicle synthetic trajectory
# Current generating 408th vehicle synthetic trajectory
# Current generating 409th vehicle synthetic trajectory
# Current generating 410th vehicle synthetic trajectory
# Current generating 411th vehicle synthetic trajectory
# Current generating 412th vehicle synthetic trajectory
# Current generating 413th vehicle synthetic trajectory
# Current generating 414th vehicle synthetic trajectory
# Current generating 415th vehicle synthetic trajectory
# Current generating 416th vehicle synthetic trajectory
# Current generating 417th vehicle synthetic trajectory
# Current generating 418th vehicle synthetic trajectory
# Current generating 419th vehicle synthetic trajectory
# Current generating 420th vehicle synthetic trajectory
# Current generating 421th vehicle synthetic trajectory
# Current generating 422th vehicle synthetic trajectory
# Current generating 423th vehicle synthetic trajectory
# Current generating 424th vehicle synthetic trajectory
# Current generating 425th vehicle synthetic trajectory
# Current generating 426th vehicle synthetic trajectory
# Current generating 427th vehicle synthetic trajectory
# Current generating 428th vehicle synthetic trajectory
# Current generating 429th vehicle synthetic trajectory
# Current generating 430th vehicle synthetic trajectory
# Current generating 431th vehicle synthetic trajectory
# Current generating 432th vehicle synthetic trajectory
# Current generating 433th vehicle synthetic trajectory
# Current generating 434th vehicle synthetic trajectory
# Current generating 435th vehicle synthetic trajectory
# Current generating 436th vehicle synthetic trajectory
# Current generating 437th vehicle synthetic trajectory
# Current generating 438th vehicle synthetic trajectory
# Current generating 439th vehicle synthetic trajectory
# Current generating 440th vehicle synthetic trajectory
# Current generating 441th vehicle synthetic trajectory
# Current generating 442th vehicle synthetic trajectory
# Current generating 443th vehicle synthetic trajectory
# Current generating 444th vehicle synthetic trajectory
# Current generating 445th vehicle synthetic trajectory
# Current generating 446th vehicle synthetic trajectory
# Current generating 447th vehicle synthetic trajectory
# Current generating 448th vehicle synthetic trajectory
# Current generating 449th vehicle synthetic trajectory
# Current generating 450th vehicle synthetic trajectory
# Current generating 451th vehicle synthetic trajectory
# Current generating 452th vehicle synthetic trajectory
# Current generating 453th vehicle synthetic trajectory
# Current generating 454th vehicle synthetic trajectory
# Current generating 455th vehicle synthetic trajectory
# Current generating 456th vehicle synthetic trajectory
# Current generating 457th vehicle synthetic trajectory
# Current generating 458th vehicle synthetic trajectory
# Current generating 459th vehicle synthetic trajectory
# Current generating 460th vehicle synthetic trajectory
# Current generating 461th vehicle synthetic trajectory
# Current generating 462th vehicle synthetic trajectory
# Current generating 463th vehicle synthetic trajectory
# Current generating 464th vehicle synthetic trajectory
# Current generating 465th vehicle synthetic trajectory
# Current generating 466th vehicle synthetic trajectory
# Current generating 467th vehicle synthetic trajectory
# Current generating 468th vehicle synthetic trajectory
# Current generating 469th vehicle synthetic trajectory
# Current generating 470th vehicle synthetic trajectory
# Current generating 471th vehicle synthetic trajectory
# Current generating 472th vehicle synthetic trajectory
# Current generating 473th vehicle synthetic trajectory
# Current generating 474th vehicle synthetic trajectory
# Current generating 475th vehicle synthetic trajectory
# Current generating 476th vehicle synthetic trajectory
# Current generating 477th vehicle synthetic trajectory
# Current generating 478th vehicle synthetic trajectory
# Current generating 479th vehicle synthetic trajectory
# Current generating 480th vehicle synthetic trajectory
# Current generating 481th vehicle synthetic trajectory
# Current generating 482th vehicle synthetic trajectory
# Current generating 483th vehicle synthetic trajectory
# Current generating 484th vehicle synthetic trajectory
# Current generating 485th vehicle synthetic trajectory
# Current generating 486th vehicle synthetic trajectory
# Current generating 487th vehicle synthetic trajectory
# Current generating 488th vehicle synthetic trajectory
# Current generating 489th vehicle synthetic trajectory
# Current generating 490th vehicle synthetic trajectory
# Current generating 491th vehicle synthetic trajectory
# Current generating 492th vehicle synthetic trajectory
# Current generating 493th vehicle synthetic trajectory
# Current generating 494th vehicle synthetic trajectory
# Current generating 495th vehicle synthetic trajectory
# Current generating 496th vehicle synthetic trajectory
# Current generating 497th vehicle synthetic trajectory
# Current generating 498th vehicle synthetic trajectory
# Current generating 499th vehicle synthetic trajectory
# Current generating 500th vehicle synthetic trajectory
# Current generating 501th vehicle synthetic trajectory
# Current generating 502th vehicle synthetic trajectory
# Current generating 503th vehicle synthetic trajectory
# Current generating 504th vehicle synthetic trajectory
# Current generating 505th vehicle synthetic trajectory
# Current generating 506th vehicle synthetic trajectory
# Current generating 507th vehicle synthetic trajectory
# Current generating 508th vehicle synthetic trajectory
# Current generating 509th vehicle synthetic trajectory
# Current generating 510th vehicle synthetic trajectory
# Current generating 511th vehicle synthetic trajectory
# Current generating 512th vehicle synthetic trajectory
# Current generating 513th vehicle synthetic trajectory
# Current generating 514th vehicle synthetic trajectory
# Current generating 515th vehicle synthetic trajectory
# Current generating 516th vehicle synthetic trajectory
# Current generating 517th vehicle synthetic trajectory
# Current generating 518th vehicle synthetic trajectory
# Current generating 519th vehicle synthetic trajectory
# Current generating 520th vehicle synthetic trajectory
# Current generating 521th vehicle synthetic trajectory
# Current generating 522th vehicle synthetic trajectory
# Current generating 523th vehicle synthetic trajectory
# Current generating 524th vehicle synthetic trajectory
# Current generating 525th vehicle synthetic trajectory
# Current generating 526th vehicle synthetic trajectory
# Current generating 527th vehicle synthetic trajectory
# Current generating 528th vehicle synthetic trajectory
# Current generating 529th vehicle synthetic trajectory
# Current generating 530th vehicle synthetic trajectory
# Current generating 531th vehicle synthetic trajectory
# Current generating 532th vehicle synthetic trajectory
# Current generating 533th vehicle synthetic trajectory
# Current generating 534th vehicle synthetic trajectory
# Current generating 535th vehicle synthetic trajectory
# Current generating 536th vehicle synthetic trajectory
# Current generating 537th vehicle synthetic trajectory
# Current generating 538th vehicle synthetic trajectory
# Current generating 539th vehicle synthetic trajectory
# Current generating 540th vehicle synthetic trajectory
# Current generating 541th vehicle synthetic trajectory
# Current generating 542th vehicle synthetic trajectory
# Current generating 543th vehicle synthetic trajectory
# Current generating 544th vehicle synthetic trajectory
# Current generating 545th vehicle synthetic trajectory
# Current generating 546th vehicle synthetic trajectory
# Current generating 547th vehicle synthetic trajectory
# Current generating 548th vehicle synthetic trajectory
# Current generating 549th vehicle synthetic trajectory
# Current generating 550th vehicle synthetic trajectory
# Current generating 551th vehicle synthetic trajectory
# Current generating 552th vehicle synthetic trajectory
# Current generating 553th vehicle synthetic trajectory
# Current generating 554th vehicle synthetic trajectory
# Current generating 555th vehicle synthetic trajectory
# Current generating 556th vehicle synthetic trajectory
# Current generating 557th vehicle synthetic trajectory
# Current generating 558th vehicle synthetic trajectory
# Current generating 559th vehicle synthetic trajectory
# Current generating 560th vehicle synthetic trajectory
# Current generating 561th vehicle synthetic trajectory
# Current generating 562th vehicle synthetic trajectory
# Current generating 563th vehicle synthetic trajectory
# Current generating 564th vehicle synthetic trajectory
# Current generating 565th vehicle synthetic trajectory
# Current generating 566th vehicle synthetic trajectory
# Current generating 567th vehicle synthetic trajectory
# Current generating 568th vehicle synthetic trajectory
# Current generating 569th vehicle synthetic trajectory
# Current generating 570th vehicle synthetic trajectory
# Current generating 571th vehicle synthetic trajectory
# Current generating 572th vehicle synthetic trajectory
# Current generating 573th vehicle synthetic trajectory
# Current generating 574th vehicle synthetic trajectory
# Current generating 575th vehicle synthetic trajectory
# Current generating 576th vehicle synthetic trajectory
# Current generating 577th vehicle synthetic trajectory
# Current generating 578th vehicle synthetic trajectory
# Current generating 579th vehicle synthetic trajectory
# Current generating 580th vehicle synthetic trajectory
# Current generating 581th vehicle synthetic trajectory
# Current generating 582th vehicle synthetic trajectory
# Current generating 583th vehicle synthetic trajectory
# Current generating 584th vehicle synthetic trajectory
# Current generating 585th vehicle synthetic trajectory
# Current generating 586th vehicle synthetic trajectory
# Current generating 587th vehicle synthetic trajectory
# Current generating 588th vehicle synthetic trajectory
# Current generating 589th vehicle synthetic trajectory
# Current generating 590th vehicle synthetic trajectory
# Current generating 591th vehicle synthetic trajectory
# Current generating 592th vehicle synthetic trajectory
# Current generating 593th vehicle synthetic trajectory
# Current generating 594th vehicle synthetic trajectory
# Current generating 595th vehicle synthetic trajectory
# Current generating 596th vehicle synthetic trajectory
# Current generating 597th vehicle synthetic trajectory
# Current generating 598th vehicle synthetic trajectory
# Current generating 599th vehicle synthetic trajectory
# Current generating 600th vehicle synthetic trajectory
# Current generating 601th vehicle synthetic trajectory
# Current generating 602th vehicle synthetic trajectory
# Current generating 603th vehicle synthetic trajectory
# Current generating 604th vehicle synthetic trajectory
# Current generating 605th vehicle synthetic trajectory
# Current generating 606th vehicle synthetic trajectory
# Current generating 607th vehicle synthetic trajectory
# Current generating 608th vehicle synthetic trajectory
# Current generating 609th vehicle synthetic trajectory
# Current generating 610th vehicle synthetic trajectory
# Current generating 611th vehicle synthetic trajectory
# Current generating 612th vehicle synthetic trajectory
# Current generating 613th vehicle synthetic trajectory
# Current generating 614th vehicle synthetic trajectory
# Current generating 615th vehicle synthetic trajectory
# Current generating 616th vehicle synthetic trajectory
# Current generating 617th vehicle synthetic trajectory
# Current generating 618th vehicle synthetic trajectory
# Current generating 619th vehicle synthetic trajectory
# Current generating 620th vehicle synthetic trajectory
# Current generating 621th vehicle synthetic trajectory
# Current generating 622th vehicle synthetic trajectory
# Current generating 623th vehicle synthetic trajectory
# Current generating 624th vehicle synthetic trajectory
# Current generating 625th vehicle synthetic trajectory
# Current generating 626th vehicle synthetic trajectory
# Current generating 627th vehicle synthetic trajectory
# Current generating 628th vehicle synthetic trajectory
# Current generating 629th vehicle synthetic trajectory
# Current generating 630th vehicle synthetic trajectory
# Current generating 631th vehicle synthetic trajectory
# Current generating 632th vehicle synthetic trajectory
# Current generating 633th vehicle synthetic trajectory
# Current generating 634th vehicle synthetic trajectory
# Current generating 635th vehicle synthetic trajectory
# Current generating 636th vehicle synthetic trajectory
# Current generating 637th vehicle synthetic trajectory
# Current generating 638th vehicle synthetic trajectory
# Current generating 639th vehicle synthetic trajectory
# Current generating 640th vehicle synthetic trajectory
# Current generating 641th vehicle synthetic trajectory
# Current generating 642th vehicle synthetic trajectory
# Current generating 643th vehicle synthetic trajectory
# Current generating 644th vehicle synthetic trajectory
# Current generating 645th vehicle synthetic trajectory
# Current generating 646th vehicle synthetic trajectory
# Current generating 647th vehicle synthetic trajectory
# Current generating 648th vehicle synthetic trajectory
# Current generating 649th vehicle synthetic trajectory
# Current generating 650th vehicle synthetic trajectory
# Current generating 651th vehicle synthetic trajectory
# Current generating 652th vehicle synthetic trajectory
# Current generating 653th vehicle synthetic trajectory
# Current generating 654th vehicle synthetic trajectory
# Current generating 655th vehicle synthetic trajectory
# Current generating 656th vehicle synthetic trajectory
# Current generating 657th vehicle synthetic trajectory
# Current generating 658th vehicle synthetic trajectory
# Current generating 659th vehicle synthetic trajectory
# Current generating 660th vehicle synthetic trajectory
# Current generating 661th vehicle synthetic trajectory
# Current generating 662th vehicle synthetic trajectory
# Current generating 663th vehicle synthetic trajectory
# Current generating 664th vehicle synthetic trajectory
# Current generating 665th vehicle synthetic trajectory
# Current generating 666th vehicle synthetic trajectory
# Current generating 667th vehicle synthetic trajectory
# Current generating 668th vehicle synthetic trajectory
# Current generating 669th vehicle synthetic trajectory
# Current generating 670th vehicle synthetic trajectory
# Current generating 671th vehicle synthetic trajectory
# Current generating 672th vehicle synthetic trajectory
# Current generating 673th vehicle synthetic trajectory
# Current generating 674th vehicle synthetic trajectory
# Current generating 675th vehicle synthetic trajectory
# Current generating 676th vehicle synthetic trajectory
# Current generating 677th vehicle synthetic trajectory
# Current generating 678th vehicle synthetic trajectory
# Current generating 679th vehicle synthetic trajectory
# Current generating 680th vehicle synthetic trajectory
# Current generating 681th vehicle synthetic trajectory
# Current generating 682th vehicle synthetic trajectory
# Current generating 683th vehicle synthetic trajectory
# Current generating 684th vehicle synthetic trajectory
# Current generating 685th vehicle synthetic trajectory
# Current generating 686th vehicle synthetic trajectory
# Current generating 687th vehicle synthetic trajectory
# Current generating 688th vehicle synthetic trajectory
# Current generating 689th vehicle synthetic trajectory
# Current generating 690th vehicle synthetic trajectory
# Current generating 691th vehicle synthetic trajectory
# Current generating 692th vehicle synthetic trajectory
# Current generating 693th vehicle synthetic trajectory
# Current generating 694th vehicle synthetic trajectory
# Current generating 695th vehicle synthetic trajectory
# Current generating 696th vehicle synthetic trajectory
# Current generating 697th vehicle synthetic trajectory
# Current generating 698th vehicle synthetic trajectory
# Current generating 699th vehicle synthetic trajectory
# Current generating 700th vehicle synthetic trajectory
# Current generating 701th vehicle synthetic trajectory
# Current generating 702th vehicle synthetic trajectory
# Current generating 703th vehicle synthetic trajectory
# Current generating 704th vehicle synthetic trajectory
# Current generating 705th vehicle synthetic trajectory
# Current generating 706th vehicle synthetic trajectory
# Current generating 707th vehicle synthetic trajectory
# Current generating 708th vehicle synthetic trajectory
# Current generating 709th vehicle synthetic trajectory
# Current generating 710th vehicle synthetic trajectory
# Current generating 711th vehicle synthetic trajectory
# Current generating 712th vehicle synthetic trajectory
# Current generating 713th vehicle synthetic trajectory
# Current generating 714th vehicle synthetic trajectory
# Current generating 715th vehicle synthetic trajectory
# Current generating 716th vehicle synthetic trajectory
# Current generating 717th vehicle synthetic trajectory
# Current generating 718th vehicle synthetic trajectory
# Current generating 719th vehicle synthetic trajectory
# Current generating 720th vehicle synthetic trajectory
# Current generating 721th vehicle synthetic trajectory
# Current generating 722th vehicle synthetic trajectory
# Current generating 723th vehicle synthetic trajectory
# Current generating 724th vehicle synthetic trajectory
# Current generating 725th vehicle synthetic trajectory
# Current generating 726th vehicle synthetic trajectory
# Current generating 727th vehicle synthetic trajectory
# Current generating 728th vehicle synthetic trajectory
# Current generating 729th vehicle synthetic trajectory
# Current generating 730th vehicle synthetic trajectory
# Current generating 731th vehicle synthetic trajectory
# Current generating 732th vehicle synthetic trajectory
# Current generating 733th vehicle synthetic trajectory
# Current generating 734th vehicle synthetic trajectory
# Current generating 735th vehicle synthetic trajectory
# Current generating 736th vehicle synthetic trajectory
# Current generating 737th vehicle synthetic trajectory
# Current generating 738th vehicle synthetic trajectory
# Current generating 739th vehicle synthetic trajectory
# Current generating 740th vehicle synthetic trajectory
# Current generating 741th vehicle synthetic trajectory
# Current generating 742th vehicle synthetic trajectory
# Current generating 743th vehicle synthetic trajectory
# Current generating 744th vehicle synthetic trajectory
# Current generating 745th vehicle synthetic trajectory
# Current generating 746th vehicle synthetic trajectory
# Current generating 747th vehicle synthetic trajectory
# Current generating 748th vehicle synthetic trajectory
# Current generating 749th vehicle synthetic trajectory
# Current generating 750th vehicle synthetic trajectory
# Current generating 751th vehicle synthetic trajectory
# Current generating 752th vehicle synthetic trajectory
# Current generating 753th vehicle synthetic trajectory
# Current generating 754th vehicle synthetic trajectory
# Current generating 755th vehicle synthetic trajectory
# Current generating 756th vehicle synthetic trajectory
# Current generating 757th vehicle synthetic trajectory
# Current generating 758th vehicle synthetic trajectory
# Current generating 759th vehicle synthetic trajectory
# Current generating 760th vehicle synthetic trajectory
# Current generating 761th vehicle synthetic trajectory
# Current generating 762th vehicle synthetic trajectory
# Current generating 763th vehicle synthetic trajectory
# Current generating 764th vehicle synthetic trajectory
# Current generating 765th vehicle synthetic trajectory
# Current generating 766th vehicle synthetic trajectory
# Current generating 767th vehicle synthetic trajectory
# Current generating 768th vehicle synthetic trajectory
# Current generating 769th vehicle synthetic trajectory
# Current generating 770th vehicle synthetic trajectory
# Current generating 771th vehicle synthetic trajectory
# Current generating 772th vehicle synthetic trajectory
# Current generating 773th vehicle synthetic trajectory
# Current generating 774th vehicle synthetic trajectory
# Current generating 775th vehicle synthetic trajectory
# Current generating 776th vehicle synthetic trajectory
# Current generating 777th vehicle synthetic trajectory
# Current generating 778th vehicle synthetic trajectory
# Current generating 779th vehicle synthetic trajectory
# Current generating 780th vehicle synthetic trajectory
# Current generating 781th vehicle synthetic trajectory
# Current generating 782th vehicle synthetic trajectory
# Current generating 783th vehicle synthetic trajectory
# Current generating 784th vehicle synthetic trajectory
# Current generating 785th vehicle synthetic trajectory
# Current generating 786th vehicle synthetic trajectory
# Current generating 787th vehicle synthetic trajectory
# Current generating 788th vehicle synthetic trajectory
# Current generating 789th vehicle synthetic trajectory
# Current generating 790th vehicle synthetic trajectory
# Current generating 791th vehicle synthetic trajectory
# Current generating 792th vehicle synthetic trajectory
# Current generating 793th vehicle synthetic trajectory
# Current generating 794th vehicle synthetic trajectory
# Current generating 795th vehicle synthetic trajectory
# Current generating 796th vehicle synthetic trajectory
# Current generating 797th vehicle synthetic trajectory
# Current generating 798th vehicle synthetic trajectory
# Current generating 799th vehicle synthetic trajectory
# Current generating 800th vehicle synthetic trajectory
# Current generating 801th vehicle synthetic trajectory
# Current generating 802th vehicle synthetic trajectory
# Current generating 803th vehicle synthetic trajectory
# Current generating 804th vehicle synthetic trajectory
# Current generating 805th vehicle synthetic trajectory
# Current generating 806th vehicle synthetic trajectory
# Current generating 807th vehicle synthetic trajectory
# Current generating 808th vehicle synthetic trajectory
# Current generating 809th vehicle synthetic trajectory
# Current generating 810th vehicle synthetic trajectory
# Current generating 811th vehicle synthetic trajectory
# Current generating 812th vehicle synthetic trajectory
# Current generating 813th vehicle synthetic trajectory
# Current generating 814th vehicle synthetic trajectory
# Current generating 815th vehicle synthetic trajectory
# Current generating 816th vehicle synthetic trajectory
# Current generating 817th vehicle synthetic trajectory
# Current generating 818th vehicle synthetic trajectory
# Current generating 819th vehicle synthetic trajectory
# Current generating 820th vehicle synthetic trajectory
# Current generating 821th vehicle synthetic trajectory
# Current generating 822th vehicle synthetic trajectory
# Current generating 823th vehicle synthetic trajectory
# Current generating 824th vehicle synthetic trajectory
# Current generating 825th vehicle synthetic trajectory
# Current generating 826th vehicle synthetic trajectory
# Current generating 827th vehicle synthetic trajectory
# Current generating 828th vehicle synthetic trajectory
# Current generating 829th vehicle synthetic trajectory
# Current generating 830th vehicle synthetic trajectory
# Current generating 831th vehicle synthetic trajectory
# Current generating 832th vehicle synthetic trajectory
# Current generating 833th vehicle synthetic trajectory
# Current generating 834th vehicle synthetic trajectory
# Current generating 835th vehicle synthetic trajectory
# Current generating 836th vehicle synthetic trajectory
# Current generating 837th vehicle synthetic trajectory
# Current generating 838th vehicle synthetic trajectory
# Current generating 839th vehicle synthetic trajectory
# Current generating 840th vehicle synthetic trajectory
# Current generating 841th vehicle synthetic trajectory
# Current generating 842th vehicle synthetic trajectory
# Current generating 843th vehicle synthetic trajectory
# Current generating 844th vehicle synthetic trajectory
# Current generating 845th vehicle synthetic trajectory
# Current generating 846th vehicle synthetic trajectory
# Current generating 847th vehicle synthetic trajectory
# Current generating 848th vehicle synthetic trajectory
# Current generating 849th vehicle synthetic trajectory
# Current generating 850th vehicle synthetic trajectory
# Current generating 851th vehicle synthetic trajectory
# Current generating 852th vehicle synthetic trajectory
# Current generating 853th vehicle synthetic trajectory
# Current generating 854th vehicle synthetic trajectory
# Current generating 855th vehicle synthetic trajectory
# Current generating 856th vehicle synthetic trajectory
# Current generating 857th vehicle synthetic trajectory
# Current generating 858th vehicle synthetic trajectory
# Current generating 859th vehicle synthetic trajectory
# Current generating 860th vehicle synthetic trajectory
# Current generating 861th vehicle synthetic trajectory
# Current generating 862th vehicle synthetic trajectory
# Current generating 863th vehicle synthetic trajectory
# Current generating 864th vehicle synthetic trajectory
# Current generating 865th vehicle synthetic trajectory
# Current generating 866th vehicle synthetic trajectory
# Current generating 867th vehicle synthetic trajectory
# Current generating 868th vehicle synthetic trajectory
# Current generating 869th vehicle synthetic trajectory
# Current generating 870th vehicle synthetic trajectory
# Current generating 871th vehicle synthetic trajectory
# Current generating 872th vehicle synthetic trajectory
# Current generating 873th vehicle synthetic trajectory
# Current generating 874th vehicle synthetic trajectory
# Current generating 875th vehicle synthetic trajectory
# Current generating 876th vehicle synthetic trajectory
# Current generating 877th vehicle synthetic trajectory
# Current generating 878th vehicle synthetic trajectory
# Current generating 879th vehicle synthetic trajectory
# Current generating 880th vehicle synthetic trajectory
# Current generating 881th vehicle synthetic trajectory
# Current generating 882th vehicle synthetic trajectory
# Current generating 883th vehicle synthetic trajectory
# Current generating 884th vehicle synthetic trajectory
# Current generating 885th vehicle synthetic trajectory
# Current generating 886th vehicle synthetic trajectory
# Current generating 887th vehicle synthetic trajectory
# Current generating 888th vehicle synthetic trajectory
# Current generating 889th vehicle synthetic trajectory
# Current generating 890th vehicle synthetic trajectory
# Current generating 891th vehicle synthetic trajectory
# Current generating 892th vehicle synthetic trajectory
# Current generating 893th vehicle synthetic trajectory
# Current generating 894th vehicle synthetic trajectory
# Current generating 895th vehicle synthetic trajectory
# Current generating 896th vehicle synthetic trajectory
# Current generating 897th vehicle synthetic trajectory
# Current generating 898th vehicle synthetic trajectory
# Current generating 899th vehicle synthetic trajectory
# Current generating 900th vehicle synthetic trajectory
# Current generating 901th vehicle synthetic trajectory
# Current generating 902th vehicle synthetic trajectory
# Current generating 903th vehicle synthetic trajectory
# Current generating 904th vehicle synthetic trajectory
# Current generating 905th vehicle synthetic trajectory
# Current generating 906th vehicle synthetic trajectory
# Current generating 907th vehicle synthetic trajectory
# Current generating 908th vehicle synthetic trajectory
# Current generating 909th vehicle synthetic trajectory
# Current generating 910th vehicle synthetic trajectory
# Current generating 911th vehicle synthetic trajectory
# Current generating 912th vehicle synthetic trajectory
# Current generating 913th vehicle synthetic trajectory
# Current generating 914th vehicle synthetic trajectory
# Current generating 915th vehicle synthetic trajectory
# Current generating 916th vehicle synthetic trajectory
# Current generating 917th vehicle synthetic trajectory
# Current generating 918th vehicle synthetic trajectory
# Current generating 919th vehicle synthetic trajectory
# Current generating 920th vehicle synthetic trajectory
# Current generating 921th vehicle synthetic trajectory
# Current generating 922th vehicle synthetic trajectory
# Current generating 923th vehicle synthetic trajectory
# Current generating 924th vehicle synthetic trajectory
# Current generating 925th vehicle synthetic trajectory
# Current generating 926th vehicle synthetic trajectory
# Current generating 927th vehicle synthetic trajectory
# Current generating 928th vehicle synthetic trajectory
# Current generating 929th vehicle synthetic trajectory
# Current generating 930th vehicle synthetic trajectory
# Current generating 931th vehicle synthetic trajectory
# Current generating 932th vehicle synthetic trajectory
# Current generating 933th vehicle synthetic trajectory
# Current generating 934th vehicle synthetic trajectory
# Current generating 935th vehicle synthetic trajectory
# Current generating 936th vehicle synthetic trajectory
# Current generating 937th vehicle synthetic trajectory
# Current generating 938th vehicle synthetic trajectory
# Current generating 939th vehicle synthetic trajectory
# Current generating 940th vehicle synthetic trajectory
# Current generating 941th vehicle synthetic trajectory
# Current generating 942th vehicle synthetic trajectory
# Current generating 943th vehicle synthetic trajectory
# Current generating 944th vehicle synthetic trajectory
# Current generating 945th vehicle synthetic trajectory
# Current generating 946th vehicle synthetic trajectory
# Current generating 947th vehicle synthetic trajectory
# Current generating 948th vehicle synthetic trajectory
# Current generating 949th vehicle synthetic trajectory
# Current generating 950th vehicle synthetic trajectory
# Current generating 951th vehicle synthetic trajectory
# Current generating 952th vehicle synthetic trajectory
# Current generating 953th vehicle synthetic trajectory
# Current generating 954th vehicle synthetic trajectory
# Current generating 955th vehicle synthetic trajectory
# Current generating 956th vehicle synthetic trajectory
# Current generating 957th vehicle synthetic trajectory
# Current generating 958th vehicle synthetic trajectory
# Current generating 959th vehicle synthetic trajectory
# Current generating 960th vehicle synthetic trajectory
# Current generating 961th vehicle synthetic trajectory
# Current generating 962th vehicle synthetic trajectory
# Current generating 963th vehicle synthetic trajectory
# Current generating 964th vehicle synthetic trajectory
# Current generating 965th vehicle synthetic trajectory
# Current generating 966th vehicle synthetic trajectory
# Current generating 967th vehicle synthetic trajectory
# Current generating 968th vehicle synthetic trajectory
# Current generating 969th vehicle synthetic trajectory
# Current generating 970th vehicle synthetic trajectory
# Current generating 971th vehicle synthetic trajectory
# Current generating 972th vehicle synthetic trajectory
# Current generating 973th vehicle synthetic trajectory
# Current generating 974th vehicle synthetic trajectory
# Current generating 975th vehicle synthetic trajectory
# Current generating 976th vehicle synthetic trajectory
# Current generating 977th vehicle synthetic trajectory
# Current generating 978th vehicle synthetic trajectory
# Current generating 979th vehicle synthetic trajectory
# Current generating 980th vehicle synthetic trajectory
# Current generating 981th vehicle synthetic trajectory
# Current generating 982th vehicle synthetic trajectory
# Current generating 983th vehicle synthetic trajectory
# Current generating 984th vehicle synthetic trajectory
# Current generating 985th vehicle synthetic trajectory
# Current generating 986th vehicle synthetic trajectory
# Current generating 987th vehicle synthetic trajectory
# Current generating 988th vehicle synthetic trajectory
# Current generating 989th vehicle synthetic trajectory
# Current generating 990th vehicle synthetic trajectory
# Current generating 991th vehicle synthetic trajectory
# Current generating 992th vehicle synthetic trajectory
# Current generating 993th vehicle synthetic trajectory
# Current generating 994th vehicle synthetic trajectory
# Current generating 995th vehicle synthetic trajectory
# Current generating 996th vehicle synthetic trajectory
# Current generating 997th vehicle synthetic trajectory
# Current generating 998th vehicle synthetic trajectory
# Current generating 999th vehicle synthetic trajectory
